# %% [markdown]
# # Standard Deviation and Variance

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

incomes = np.random.normal(100.0, 50.0, 10000)

plt.hist(incomes, 50)
plt.show()

# %%
print('La variacion estandar del arreglo de datos es..',incomes.std())
# Out:
# La variacion estandar del arreglo de datos es.. 49.82035597491643

# %%
print('La varianza del arreglo de datos es..',incomes.var())
# Out:
# La varianza del arreglo de datos es.. 2482.067869467391

# %% [markdown]
# ## Activity

# %% [markdown]
# Experiment with different parameters on the normal function, and see what effect it has on the shape of the distribution. How does that new shape relate to the standard deviation and variance?
